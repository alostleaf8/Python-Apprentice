# %% [markdown]
# # **Lists**
#
# One of the most useful data structures in Python is a <span title="A list is a built-in data structure used to store an ordered collection of items." style="cursor: help">**list**<svg style="width:18px;height:18px; vertical-align: middle; margin-left: 2px; margin-bottom: 3px;" viewBox="0 0 24 24"><path fill="currentColor" d="M12,2A10,10 0 0,0 2,12A10,10 0 0,0 12,22A10,10 0 0,0 22,12A10,10 0 0,0 12,2M12,4A8,8 0 0,1 20,12A8,8 0 0,1 12,20A8,8 0 0,1 4,12A8,8 0 0,1 12,4M11,16.5V11.5H13V16.5H11M11,9.5V7.5H13V9.5H11Z"/></svg></span>. Grocery lists are a good way to think about them, as they keep an ordered collection of items you can look up or change, like this:
#
# Things To Buy:
# - `Apples`
# - `Oranges`
# - `Bread`
# - `Milk`
#
#  But in Python we write lists using square brackets, like this:

# %%
# Run Me!

things_to_buy = ['apples', 'oranges', 'bread', 'milk']
things_to_buy # This just displays the list so you can see it
# Out:
# ['apples', 'oranges', 'bread', 'milk']

# %% [markdown]
# ### **Indexing**
#
# You can use `[` and `]` with a number to get a single item. Since numbers in Python start at 0, the first index item is `things_to_buy[0]`.
#
# Try the example below to see indexing in action.

# %%
# Run Me!

things_to_buy = ['apples', 'oranges', 'bread', 'milk']
things_to_buy[1] # This gets the second item (index 1)
# Out:
# 'oranges'

# %% [markdown]
# ### **Iterating**
#
# You can loop over a list to do something with each item. This is
# called iteration and is very common in programs. The example below prints each
# item in the list.

# %%
# Run Me!
things_to_buy = ['apples', 'oranges', 'bread', 'milk']
for item in things_to_buy:
    print(item)
# Out:
# apples
# oranges
# bread
# milk

# %% [markdown]
# ### **Helpful list operations**
#
# Here are a few examples of common things you can do with lists:
#
# | Operation | Description |
# | :--- | :--- |
# | `append(x)` | adds `x` to the end |
# | `insert(i, x)` | inserts `x` at index `i` |
# | `remove(x)` | removes the first occurrence of `x` |
# | `len(list)` | gets the number of items |
# | `list[start:stop]` | returns a sub-list (slicing) |

# %%
# Run Me!

items = ['apple', 'banana']
print('Start:', items)

items.append('cherry')
print('After append:', items)

items.insert(1, 'orange')
print('After insert:', items)

items.remove('banana')
print('After remove:', items)
print('Length:', len(items))
print('Slice (0:3):', items[0:3])
# Out:
# Start: ['apple', 'banana']
# After append: ['apple', 'banana', 'cherry']
# After insert: ['apple', 'orange', 'banana', 'cherry']
# After remove: ['apple', 'orange', 'cherry']
# Length: 3
# Slice (0:3): ['apple', 'orange', 'cherry']

# %% [markdown]
# There is a lot more you can do with lists (sorting, nested lists, and more),
# but this covers the basics you need for our lessons.

# %% [markdown]
# ## **Lists and Tina**
#
# Lists are useful in graphics programs too. For example, you can store colors in a list and loop over them to draw each side in a different color:

# %%
# Run Me!

# %run .lib/auto_turtle.py                # This just handles the general imports for you

tina = turtle(myTS)                     # type: ignore[name-defined] - Creates a turtle named tina
tina.shape('turtle')                    # Set the shape of the turtle to a turtle
tina.speed(2)                           # Make the turtle move as fast, but not too fast

forward = 100
left = 90
colors = [ 'red', 'blue', 'black', 'orange']

for color in colors:
    tina.color(color)
    tina.forward(forward)
    tina.left(left)

# %% [markdown]
# Or, we could use a list to change the angle that tina turns:

# %%
# %run .lib/auto_turtle.py                # This just handles the general imports for you

tina = turtle(myTS)                     # type: ignore[name-defined] - Creates a turtle named tina
tina.shape('turtle')                    # Set the shape of the turtle to a turtle
tina.speed(2)                           # Make the turtle move as fast, but not too fast

forward = 100

for angle in [90, 90, 90, 90]:
    tina.forward(forward)
    tina.left(angle)

# %% [markdown]
# ## **Exercises (Optional)**
#
# If you are looking for more practice, try to complete the following exercises:

# %%
# Exercise 1 - Favorite Foods

# Create a list called `favorite_foods` with 5 items
# your code here
favorite_foods = ['paneer' , 'chicken', 'fish', 'pasta', 'salad']
# favorite_foods is what has been put to only display what is in my list above 

# Now use a loop to print each food
# your code here

for foods in favorite_foods:
    print(foods)
# Out:
# paneer
# chicken
# fish
# pasta
# salad

# %%
# Exercise 2 - Modify Numbers

# Using the list below, append 4, insert 0 at the start, and remove 2.
numbers = [1, 2, 3]

# your code here

# printing the numbers 1, 2, 3 without any changes 
print('Start:', numbers)

# adding 4 to the end {* append 4}
numbers.append(4)
# printing the numbers 1, 2, 3, 4
print('After append:', numbers)

# inserting 0 to the start ({* insert 0}
numbers.insert(0, 0)
print('After insert:', numbers)

# removing the number 2 from the list
numbers.remove(2)
# printing the final product, with 4 at the end and no 2 
print('After remove:', numbers)
# Out:
# Start: [1, 2, 3]
# After append: [1, 2, 3, 4]
# After insert: [0, 1, 2, 3, 4]
# After remove: [0, 1, 3, 4]

# %%
# Exercise 3 - Tina's Angles

# Given the list of angles, print Tina's steps to turn and move forward
angles = [45, 90, 135]
# your code here
import turtle, time

tina = turtle.Turtle()
tina.shape('turtle')                    # Set the shape of the turtle to a turtle
tina.speed(2)                           # Make the turtle move as fast, but not too fast
time.sleep(1)

forward = 100

for angle in angles:
    tina.left(angle)
    tina.forward(forward)

turtle.exitonclick()
